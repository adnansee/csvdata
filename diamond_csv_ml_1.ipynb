# %%
import pandas as pd
df = pd.read_csv('diamonds.csv')
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['price'],df['depth'])

# %%
plt.scatter(df['price'],df['table'])

# %%
df1 = pd.read_csv('census-2001-ks09-borough.csv')
df1.head()
# Out:
#   Area Code             Area Name  All people aged 16 - 74  \
# 0      00AA        City of London                     6067
# 1      00AB  Barking and Dagenham                   113579
# 2      00AC                Barnet                   228123
# 3      00AD                Bexley                   156172
# 4      00AE                 Brent                   198712
#
#    People aged 16-74 - Economically active - Employees - Part-time  \
# 0                                                276
# 1                                              11509
# 2                                              21146
# 3                                              18157
# 4                                              15628
#
#    People aged 16-74 - Economically active - Employees - Full-time  \
# 0                                               3039
# 1                                              45721
# 2                                              91489
# ...

# %%
plt.scatter(df1['All people aged 16 - 74'],df1['People aged 16-74 - Economically active - Self - employed'])
